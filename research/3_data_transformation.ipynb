# %%
import os

# %%
os.chdir('D:\DataScienceProject')
# %pwd
# Out:
# 'D:\\DataScienceProject'

# %%
from dataclasses import dataclass
from pathlib import Path

@dataclass
class DataTransformationConfig:
    root_dir: Path
    data_path: Path

# %%
from src.datascience.constants import *
from src.datascience.utils.common import read_yaml, create_directories

# %%
class ConfigManager:
    def __init__(self,
            config_filepath= CONFIG_FILE_PATH,
            params_filepath= PARAMS_FILE_PATH,
            schema_filepath= SCHEMA_FILE_PATH):
        self.config= read_yaml(config_filepath)
        self.params= read_yaml(params_filepath)
        self.schema= read_yaml(schema_filepath)

        create_directories([self.config.artifacts_root])

    def get_data_transformation_config(self) -> DataTransformationConfig:
        config= self.config.data_transformation

        create_directories([config.root_dir])

        data_transformation_config=DataTransformationConfig(
            root_dir=config.root_dir,
            data_path=config.data_path
        )
        return data_transformation_config

# %%
import os
from src.datascience import logger
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
##component- Data Transformation
class DataTransformation:
    def __init__(self,config:DataTransformationConfig):
        self.config=config

    def train_test_splitting(self):
        data=pd.read_csv(self.config.data_path)

        #splitting of data
        train, test = train_test_split(data)

        train.to_csv(os.path.join(self.config.root_dir, "train.csv"), index = False)
        test.to_csv(os.path.join(self.config.root_dir, "test.csv"), index = False)
        
        logger.info("Splitted data into train n test sets")
        logger.info(train.shape)
        logger.info(test.shape)

# %%
try:
    config = ConfigManager()
    data_transformation_config=config.get_data_transformation_config()
    data_transformation=DataTransformation(config=data_transformation_config)
    data_transformation.train_test_splitting()
except Exception as e:
    raise e
# Out:
# [2025-12-08 21:24:24,045: INFO: common: yaml file: config\config.yaml loaded successfully]
# [2025-12-08 21:24:24,051: INFO: common: yaml file: params.yaml loaded successfully]
# [2025-12-08 21:24:24,054: INFO: common: yaml file: schema.yaml loaded successfully]
# [2025-12-08 21:24:24,055: INFO: common: created directory at: artifacts]
# [2025-12-08 21:24:24,057: INFO: common: created directory at: artifacts/data_transformation]
# [2025-12-08 21:24:24,116: INFO: 239587280: Splitted data into train n test sets]
# [2025-12-08 21:24:24,117: INFO: 239587280: (1199, 12)]
# [2025-12-08 21:24:24,119: INFO: 239587280: (400, 12)]
