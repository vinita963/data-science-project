# %%
example = {"key1": "Value1", "key 2": "Value 2"}

# %%
example["key1"]
# Out:
# 'Value1'

# %%
example.key1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 example.key1
#
# AttributeError: 'dict' object has no attribute 'key1'

# %%
from box import ConfigBox

# %%
example = ConfigBox({"key1": "Value1", "key 2": "Value 2"})
example.key1
# Out:
# 'Value1'

# %%
#Explaination is for ensure annotation

def product(x: int, y: int) -> int:
    return x*y

# %%
product(3, 4)
# Out:
# 12

# %%
product(3, "4")
# Out:
# '444'

# %%
from ensure import ensure_annotations

@ensure_annotations
def product(x: int, y: int) -> int:
    return x*y

# %%
product(3, "4")
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 product(3, "4")
#
# File d:\DataScienceProject\.venv\Lib\site-packages\ensure\main.py:870, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     868     if not isinstance(value, templ):
#     869         msg = "Argument {arg} of type {valt} to {f} " "does not match annotation type {t}"
# --> 870         raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
#     872 return_val = self.f(*args, **kwargs)
#     873 if not isinstance(return_val, self.return_templ):
#
# EnsureError: Argument y of type <class 'str'> to <function product at 0x00000251C3570220> does not match annotation type <class 'int'>
